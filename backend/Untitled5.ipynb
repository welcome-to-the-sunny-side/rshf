# %%
import requests

# %%
res = requests.get(
    'https://codeforces.com/api/contest.standings',
    params = {
        'contestId': '2050',
        # 'from': '1',
        'participantTypes': 'CONTESTANT,OUT_OF_COMPETITION'
    }
)

# %%
len(res.json()['result']['rows'])
# Out:
# 19973

# %%
res.json()['result']['rows'][0]
# Out:
# {'party': {'contestId': 2050,
#   'participantId': 198581268,
#   'members': [{'handle': 'tourist'}],
#   'participantType': 'OUT_OF_COMPETITION',
#   'ghost': False,
#   'startTimeSeconds': 1733409300},
#  'rank': 1,
#  'points': 7.0,
#  'penalty': 46,
#  'successfulHackCount': 0,
#  'unsuccessfulHackCount': 0,
#  'problemResults': [{'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
#    'bestSubmissionTimeSeconds': 79},
#   {'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
#    'bestSubmissionTimeSeconds': 204},
#   {'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
#    'bestSubmissionTimeSeconds': 284},
#   {'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
#    'bestSubmissionTimeSeconds': 415},
#   {'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
#    'bestSubmissionTimeSeconds': 499},
#   {'points': 1.0,
#    'rejectedAttemptCount': 0,
#    'type': 'FINAL',
# ...
