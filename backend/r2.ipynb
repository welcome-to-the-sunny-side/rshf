# %%
from app import r2_utils
import inspect

# %%
r2_utils.write_extension_data_to_r2()
# Out:
# Finished writing 10277 entries to r2
# ('https://pub-e98285daadd4482fb56021ad394144c1.r2.dev/extension_data',
#  'https://pub-e98285daadd4482fb56021ad394144c1.r2.dev/timestamp')

# %%
r2_utils.__dir__()
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__file__',
#  '__cached__',
#  '__builtins__',
#  'boto3',
#  'datetime',
#  'os',
#  'io',
#  'requests',
#  'json',
#  'db_utils',
#  'models',
#  'gzip',
#  'msgpack',
#  'load_env_file',
#  'session',
#  'region_name',
#  'endpoint_url',
#  'aws_access_key_id',
#  'aws_secret_access_key',
#  'dev_url',
#  'write_to_r2',
#  'read_from_r2',
#  'write_extension_data_to_r2',
#  'read_extension_data_from_r2']

# %%
r2_utils.read_from_r2('timestamp')
# Out:
# {'timestamp': '2025-06-02T18:24:10.547791'}
