# %%
from app.crud import fetch_and_add_contest_to_db_from_cf, update_contest_info_from_cf_api
from app.db_utils import SessionLocal
from app import models

db = SessionLocal()

# %%
fetch_and_add_contest_to_db_from_cf(db, 1890)
update_contest_info_from_cf_api(db, 1890)

# %%
db.query(models.User).filter(models.User.is_registered == False).all()
# Out:
# [<User(id=xhx114514, cf_handle='xhx114514')>,
#  <User(id=Acetyl, cf_handle='Acetyl')>,
#  <User(id=Anonymely, cf_handle='Anonymely')>,
#  <User(id=chenyifanlx, cf_handle='chenyifanlx')>,
#  <User(id=Hydroxythio, cf_handle='Hydroxythio')>,
#  <User(id=woee, cf_handle='woee')>,
#  <User(id=W1598319840, cf_handle='W1598319840')>,
#  <User(id=win1919810, cf_handle='win1919810')>,
#  <User(id=MocoOwO, cf_handle='MocoOwO')>,
#  <User(id=cjyang, cf_handle='cjyang')>,
#  <User(id=fresh_boy, cf_handle='fresh_boy')>,
#  <User(id=SmilingBraniac, cf_handle='SmilingBraniac')>,
#  <User(id=Yhs_Joker_06, cf_handle='Yhs_Joker_06')>,
#  <User(id=wgyhmwgyhm, cf_handle='wgyhmwgyhm')>,
#  <User(id=czhxm, cf_handle='czhxm')>,
#  <User(id=The_Conductor, cf_handle='The_Conductor')>,
#  <User(id=RLVxx001, cf_handle='RLVxx001')>,
#  <User(id=Beautiful_Times, cf_handle='Beautiful_Times')>,
#  <User(id=Knightmare_, cf_handle='Knightmare_')>,
#  <User(id=daduoli, cf_handle='daduoli')>,
#  <User(id=Nanashi, cf_handle='Nanashi')>,
#  <User(id=Gnihton3, cf_handle='Gnihton3')>,
#  <User(id=414sboy, cf_handle='414sboy')>,
#  <User(id=logfk, cf_handle='logfk')>,
#  <User(id=zhangmingzu, cf_handle='zhangmingzu')>,
#  <User(id=0I0acOJleHbKa, cf_handle='0I0acOJleHbKa')>,
#  <User(id=pnlong2706, cf_handle='pnlong2706')>,
#  <User(id=Kastamonu, cf_handle='Kastamonu')>,
#  <User(id=tosivanmak, cf_handle='tosivanmak')>,
#  <User(id=Prince_Daemon, cf_handle='Prince_Daemon')>,
#  <User(id=w0rdy123, cf_handle='w0rdy123')>,
#  <User(id=Kw0x1d1, cf_handle='Kw0x1d1')>,
#  <User(id=firexial, cf_handle='firexial')>,
#  <User(id=CamnO05, cf_handle='CamnO05')>,
#  <User(id=mrmoooo, cf_handle='mrmoooo')>,
#  <User(id=regain0002, cf_handle='regain0002')>,
#  <User(id=abhilash_360, cf_handle='abhilash_360')>,
#  <User(id=xprt_1, cf_handle='xprt_1')>,
#  <User(id=denilb, cf_handle='denilb')>,
#  <User(id=Geroin, cf_handle='Geroin')>,
#  <User(id=hamuim, cf_handle='hamuim')>,
#  <User(id=Chrisedyong, cf_handle='Chrisedyong')>,
#  <User(id=Asom_Majoli, cf_handle='Asom_Majoli')>,
#  <User(id=astill__, cf_handle='astill__')>,
#  <User(id=Keq1ng, cf_handle='Keq1ng')>,
#  <User(id=dmlocdmloc, cf_handle='dmlocdmloc')>,
#  <User(id=BlueScales, cf_handle='BlueScales')>,
#  <User(id=ytb2024, cf_handle='ytb2024')>,
#  <User(id=raphaelp, cf_handle='raphaelp')>,
#  <User(id=chiki_2d, cf_handle='chiki_2d')>,
#  <User(id=PurpleHanHan, cf_handle='PurpleHanHan')>,
#  <User(id=dusty.and.rusty, cf_handle='dusty.and.rusty')>,
#  <User(id=drunkhigh, cf_handle='drunkhigh')>,
#  <User(id=scutsky, cf_handle='scutsky')>,
#  <User(id=Kakarot, cf_handle='Kakarot')>,
#  <User(id=Rowlet1, cf_handle='Rowlet1')>,
#  <User(id=BibooKoseki, cf_handle='BibooKoseki')>,
#  <User(id=gamma7736, cf_handle='gamma7736')>,
#  <User(id=ezdp, cf_handle='ezdp')>,
#  <User(id=Hanari, cf_handle='Hanari')>,
#  <User(id=Ihasyou, cf_handle='Ihasyou')>,
#  <User(id=mpb, cf_handle='mpb')>,
#  <User(id=bosar31373, cf_handle='bosar31373')>,
#  <User(id=Spacestation, cf_handle='Spacestation')>,
#  <User(id=Mikunyan, cf_handle='Mikunyan')>,
#  <User(id=Probka, cf_handle='Probka')>,
#  <User(id=newbie114514, cf_handle='newbie114514')>,
#  <User(id=hhxxttxr, cf_handle='hhxxttxr')>,
#  <User(id=Blueawa, cf_handle='Blueawa')>,
#  <User(id=Ashish_verma, cf_handle='Ashish_verma')>,
#  <User(id=world_of_only_victors, cf_handle='world_of_only_victors')>,
#  <User(id=sultan__, cf_handle='sultan__')>,
#  <User(id=zyxawa, cf_handle='zyxawa')>,
#  <User(id=hungcubuso2vn, cf_handle='hungcubuso2vn')>,
#  <User(id=Minh, cf_handle='Minh')>,
#  <User(id=umezo, cf_handle='umezo')>,
#  <User(id=bleh0.5, cf_handle='bleh0.5')>,
#  <User(id=marzipan, cf_handle='marzipan')>,
#  <User(id=Alve_50, cf_handle='Alve_50')>,
#  <User(id=MrLolthe1st, cf_handle='MrLolthe1st')>,
#  <User(id=kosakkun, cf_handle='kosakkun')>,
#  <User(id=sgsonugoyalsg, cf_handle='sgsonugoyalsg')>,
#  <User(id=KejieXu, cf_handle='KejieXu')>,
#  <User(id=Hihihah, cf_handle='Hihihah')>,
#  <User(id=FlyHighh, cf_handle='FlyHighh')>,
#  <User(id=Prince_Arthas, cf_handle='Prince_Arthas')>,
#  <User(id=wwwqeqeqeqe, cf_handle='wwwqeqeqeqe')>,
#  <User(id=Rayanx_, cf_handle='Rayanx_')>,
#  <User(id=ayush_raj.21, cf_handle='ayush_raj.21')>,
#  <User(id=bedrockfake, cf_handle='bedrockfake')>,
#  <User(id=cc_lab, cf_handle='cc_lab')>,
#  <User(id=GrimTreaper, cf_handle='GrimTreaper')>,
#  <User(id=MrPizza, cf_handle='MrPizza')>,
#  <User(id=Goldenglow1427, cf_handle='Goldenglow1427')>,
#  <User(id=CountingGroup, cf_handle='CountingGroup')>,
#  <User(id=FURDREAMS, cf_handle='FURDREAMS')>,
#  <User(id=renrg, cf_handle='renrg')>,
#  <User(id=Yuuichi, cf_handle='Yuuichi')>,
#  <User(id=qhnana7mi, cf_handle='qhnana7mi')>,
#  <User(id=LiZnB_love_ZX, cf_handle='LiZnB_love_ZX')>,
#  <User(id=StrausKoldun, cf_handle='StrausKoldun')>,
#  <User(id=Zixel, cf_handle='Zixel')>,
#  <User(id=pushpavel, cf_handle='pushpavel')>,
#  <User(id=RedLeaf, cf_handle='RedLeaf')>,
#  <User(id=tryNotToJudge, cf_handle='tryNotToJudge')>,
#  <User(id=Raywithyou, cf_handle='Raywithyou')>,
#  <User(id=silly_pig, cf_handle='silly_pig')>,
#  <User(id=wcqqqqq, cf_handle='wcqqqqq')>,
#  <User(id=anonymous_01, cf_handle='anonymous_01')>,
#  <User(id=Hasib_16, cf_handle='Hasib_16')>,
#  <User(id=r_q, cf_handle='r_q')>,
#  <User(id=skyhgzsh, cf_handle='skyhgzsh')>,
#  <User(id=superyijin_txdy, cf_handle='superyijin_txdy')>,
#  <User(id=xyx., cf_handle='xyx.')>,
#  <User(id=anshkabackup, cf_handle='anshkabackup')>,
#  <User(id=N42, cf_handle='N42')>,
#  <User(id=liugenxuan, cf_handle='liugenxuan')>,
#  <User(id=dingzhen_, cf_handle='dingzhen_')>,
#  <User(id=yeshuchen, cf_handle='yeshuchen')>,
#  <User(id=wiritos, cf_handle='wiritos')>,
#  <User(id=Pavarishko, cf_handle='Pavarishko')>,
#  <User(id=BudiArb, cf_handle='BudiArb')>,
#  <User(id=flamestorm, cf_handle='flamestorm')>,
#  <User(id=introspecct, cf_handle='introspecct')>,
#  <User(id=BingHui, cf_handle='BingHui')>,
#  <User(id=liveworldlike, cf_handle='liveworldlike')>,
#  <User(id=6consoi, cf_handle='6consoi')>,
#  <User(id=WorkingTemplar, cf_handle='WorkingTemplar')>,
#  <User(id=yoraghav, cf_handle='yoraghav')>,
#  <User(id=CocoCream, cf_handle='CocoCream')>,
#  <User(id=Boris_Krasnov, cf_handle='Boris_Krasnov')>,
#  <User(id=Rippr, cf_handle='Rippr')>,
#  <User(id=sunrise10032, cf_handle='sunrise10032')>,
#  <User(id=RU_NowOrNever, cf_handle='RU_NowOrNever')>,
#  <User(id=jueeng, cf_handle='jueeng')>,
#  <User(id=SYRV, cf_handle='SYRV')>,
#  <User(id=vineeth_kada, cf_handle='vineeth_kada')>,
#  <User(id=inflation, cf_handle='inflation')>,
#  <User(id=chen910606, cf_handle='chen910606')>,
#  <User(id=xinkule, cf_handle='xinkule')>,
#  <User(id=Lirich, cf_handle='Lirich')>,
#  <User(id=CN__james1, cf_handle='CN__james1')>,
#  <User(id=northstar2010, cf_handle='northstar2010')>,
#  <User(id=Blame.k, cf_handle='Blame.k')>,
#  <User(id=Manikm, cf_handle='Manikm')>,
#  <User(id=Traws, cf_handle='Traws')>,
#  <User(id=Sky_Warrior, cf_handle='Sky_Warrior')>,
#  <User(id=chrysalis, cf_handle='chrysalis')>,
#  <User(id=adityagamer, cf_handle='adityagamer')>,
#  <User(id=Blastoise42, cf_handle='Blastoise42')>,
#  <User(id=L7Y13, cf_handle='L7Y13')>,
#  <User(id=tvladm, cf_handle='tvladm')>,
#  <User(id=Egorsa, cf_handle='Egorsa')>,
#  <User(id=WangQ, cf_handle='WangQ')>,
#  <User(id=haha_harshit, cf_handle='haha_harshit')>,
#  <User(id=i_just_practice, cf_handle='i_just_practice')>,
#  <User(id=ShadharonShompadok, cf_handle='ShadharonShompadok')>,
#  <User(id=Halberd_Cease, cf_handle='Halberd_Cease')>,
#  <User(id=4TZdhjeb, cf_handle='4TZdhjeb')>,
#  <User(id=xiachi, cf_handle='xiachi')>,
#  <User(id=peacebringer167, cf_handle='peacebringer167')>,
#  <User(id=quiescent, cf_handle='quiescent')>,
#  <User(id=juancs, cf_handle='juancs')>,
#  <User(id=Keepy, cf_handle='Keepy')>,
#  <User(id=Zadymiarz1234, cf_handle='Zadymiarz1234')>,
#  <User(id=freaksier, cf_handle='freaksier')>,
#  <User(id=reilu, cf_handle='reilu')>,
#  <User(id=rijinjjjj, cf_handle='rijinjjjj')>,
#  <User(id=ymmm_, cf_handle='ymmm_')>,
#  <User(id=dirkdirk623, cf_handle='dirkdirk623')>,
#  <User(id=nanahyakunanazhunana, cf_handle='nanahyakunanazhunana')>,
#  <User(id=margofan, cf_handle='margofan')>,
#  <User(id=YangYuDD, cf_handle='YangYuDD')>,
#  <User(id=EasonCookie197, cf_handle='EasonCookie197')>,
#  <User(id=Sohail_Kasmani, cf_handle='Sohail_Kasmani')>,
#  <User(id=nano.nish, cf_handle='nano.nish')>,
#  <User(id=SilverChariotO.o, cf_handle='SilverChariotO.o')>,
#  <User(id=alavrov, cf_handle='alavrov')>,
#  <User(id=Angriliset, cf_handle='Angriliset')>,
#  <User(id=SilviaXavier, cf_handle='SilviaXavier')>,
#  <User(id=Min_Iskander, cf_handle='Min_Iskander')>,
#  <User(id=Sorasaki_Hina, cf_handle='Sorasaki_Hina')>,
#  <User(id=gagan_6730, cf_handle='gagan_6730')>,
#  <User(id=wsday, cf_handle='wsday')>,
#  <User(id=Zhaoby, cf_handle='Zhaoby')>,
#  <User(id=krafter, cf_handle='krafter')>,
#  <User(id=Terac, cf_handle='Terac')>,
#  <User(id=tilenn, cf_handle='tilenn')>,
#  <User(id=VAntonuk, cf_handle='VAntonuk')>,
#  <User(id=btac, cf_handle='btac')>,
#  <User(id=zzh00195, cf_handle='zzh00195')>,
#  <User(id=ThiagoSDQ, cf_handle='ThiagoSDQ')>,
#  <User(id=Cryptic_42, cf_handle='Cryptic_42')>,
#  <User(id=theNewSon, cf_handle='theNewSon')>,
#  <User(id=chaeyoung_twice, cf_handle='chaeyoung_twice')>,
#  <User(id=gaurav_m7, cf_handle='gaurav_m7')>,
#  <User(id=chuquwan9964, cf_handle='chuquwan9964')>,
#  <User(id=og_prakash, cf_handle='og_prakash')>,
#  <User(id=cloud_services, cf_handle='cloud_services')>,
#  <User(id=indreshsingh, cf_handle='indreshsingh')>,
#  <User(id=defNotKritik, cf_handle='defNotKritik')>,
#  <User(id=Kun10, cf_handle='Kun10')>,
#  <User(id=Drurpp, cf_handle='Drurpp')>,
#  <User(id=kne3lb4m3, cf_handle='kne3lb4m3')>,
#  <User(id=cxhscst2, cf_handle='cxhscst2')>,
#  <User(id=OobugoO, cf_handle='OobugoO')>,
#  <User(id=fattybug, cf_handle='fattybug')>,
#  <User(id=Alumin1um, cf_handle='Alumin1um')>,
#  <User(id=utkarsh.rai, cf_handle='utkarsh.rai')>,
#  <User(id=FritzGeiger, cf_handle='FritzGeiger')>,
#  <User(id=Sahil_32, cf_handle='Sahil_32')>,
#  <User(id=Zan001, cf_handle='Zan001')>,
#  <User(id=shhy_LFB, cf_handle='shhy_LFB')>,
#  <User(id=GloryToMankind, cf_handle='GloryToMankind')>,
#  <User(id=JSR1, cf_handle='JSR1')>,
#  <User(id=AbyssSkb, cf_handle='AbyssSkb')>,
#  <User(id=jzhsh1735, cf_handle='jzhsh1735')>,
#  <User(id=Tanish.TST, cf_handle='Tanish.TST')>,
#  <User(id=lovelive__, cf_handle='lovelive__')>,
#  <User(id=Mishra_Dhruv, cf_handle='Mishra_Dhruv')>,
#  <User(id=NatanVek, cf_handle='NatanVek')>,
#  <User(id=cst7, cf_handle='cst7')>,
#  <User(id=ItsMeVivk, cf_handle='ItsMeVivk')>,
#  <User(id=lgxyes, cf_handle='lgxyes')>,
#  <User(id=RICHARD-H, cf_handle='RICHARD-H')>,
#  <User(id=tmi, cf_handle='tmi')>,
#  <User(id=Alightning, cf_handle='Alightning')>,
#  <User(id=Mikazuki_Munechika, cf_handle='Mikazuki_Munechika')>,
#  <User(id=Kusmir, cf_handle='Kusmir')>,
#  <User(id=rose_DKY, cf_handle='rose_DKY')>,
#  <User(id=GreatDevResh, cf_handle='GreatDevResh')>,
#  <User(id=Enzinho, cf_handle='Enzinho')>,
#  <User(id=Sabbir1807070, cf_handle='Sabbir1807070')>,
#  <User(id=jsh00325, cf_handle='jsh00325')>,
#  <User(id=MUZAN, cf_handle='MUZAN')>,
#  <User(id=Ianis, cf_handle='Ianis')>,
#  <User(id=sai-17, cf_handle='sai-17')>,
#  <User(id=LiuYun40066, cf_handle='LiuYun40066')>,
#  <User(id=MayLove, cf_handle='MayLove')>,
#  <User(id=RU_SFS, cf_handle='RU_SFS')>,
#  <User(id=Anemois, cf_handle='Anemois')>,
#  <User(id=nyaaaayn, cf_handle='nyaaaayn')>,
#  <User(id=shengda, cf_handle='shengda')>,
#  <User(id=KM_Parvez, cf_handle='KM_Parvez')>,
#  <User(id=mashduihca, cf_handle='mashduihca')>,
#  <User(id=ShiTieBi, cf_handle='ShiTieBi')>,
#  <User(id=Kyrizer_W, cf_handle='Kyrizer_W')>,
#  <User(id=e_mo, cf_handle='e_mo')>,
#  <User(id=mouhua, cf_handle='mouhua')>,
#  <User(id=AH-20, cf_handle='AH-20')>,
#  <User(id=vpganh, cf_handle='vpganh')>,
#  <User(id=buleeyes, cf_handle='buleeyes')>,
#  <User(id=weawemam, cf_handle='weawemam')>,
#  <User(id=6codingrohan, cf_handle='6codingrohan')>,
#  <User(id=skeep194, cf_handle='skeep194')>,
#  <User(id=zjwwjhy, cf_handle='zjwwjhy')>,
#  <User(id=panchangamakhil, cf_handle='panchangamakhil')>,
#  <User(id=kinshuk_12, cf_handle='kinshuk_12')>,
#  <User(id=O0O0O0O0O0O, cf_handle='O0O0O0O0O0O')>,
#  <User(id=Jefy, cf_handle='Jefy')>,
#  <User(id=Thebeginner_3101, cf_handle='Thebeginner_3101')>,
#  <User(id=ForgotDream_CHN, cf_handle='ForgotDream_CHN')>,
#  <User(id=doanquocthinh2004, cf_handle='doanquocthinh2004')>,
#  <User(id=Tang2, cf_handle='Tang2')>,
#  <User(id=gugubird13, cf_handle='gugubird13')>,
#  <User(id=MarcosMTR, cf_handle='MarcosMTR')>,
#  <User(id=hhhxxxyyy3, cf_handle='hhhxxxyyy3')>,
#  <User(id=BlueBlue, cf_handle='BlueBlue')>,
#  <User(id=Aviral_Gupta, cf_handle='Aviral_Gupta')>,
#  <User(id=smooth_iterator, cf_handle='smooth_iterator')>,
#  <User(id=AdletShelby, cf_handle='AdletShelby')>,
#  <User(id=itz_shubh, cf_handle='itz_shubh')>,
#  <User(id=Huseyn123, cf_handle='Huseyn123')>,
#  <User(id=kimiyowaimo, cf_handle='kimiyowaimo')>,
#  <User(id=holy_crap, cf_handle='holy_crap')>,
#  <User(id=ttt1anyu, cf_handle='ttt1anyu')>,
#  <User(id=hupeiyuan, cf_handle='hupeiyuan')>,
#  <User(id=brown-Rang, cf_handle='brown-Rang')>,
#  <User(id=SunlightZero, cf_handle='SunlightZero')>,
#  <User(id=dhsg, cf_handle='dhsg')>,
#  <User(id=chayleaf, cf_handle='chayleaf')>,
#  <User(id=ashktchm, cf_handle='ashktchm')>,
#  <User(id=windy_hill, cf_handle='windy_hill')>,
#  <User(id=Arpia, cf_handle='Arpia')>,
#  <User(id=TnMurder5000, cf_handle='TnMurder5000')>,
#  <User(id=ljfty, cf_handle='ljfty')>,
#  <User(id=SUL, cf_handle='SUL')>,
#  <User(id=tch1001, cf_handle='tch1001')>,
#  <User(id=masa.dobric, cf_handle='masa.dobric')>,
#  <User(id=ZYM, cf_handle='ZYM')>,
#  <User(id=HAPPY_JUST_OK, cf_handle='HAPPY_JUST_OK')>,
#  <User(id=crude_human, cf_handle='crude_human')>,
#  <User(id=bright_ml, cf_handle='bright_ml')>,
#  <User(id=MahmoudBassem, cf_handle='MahmoudBassem')>,
#  <User(id=jypiter, cf_handle='jypiter')>,
#  <User(id=abhaayyy, cf_handle='abhaayyy')>,
#  <User(id=Tmitmi, cf_handle='Tmitmi')>,
#  <User(id=ZmkzOWYyOHcwdWo4cj, cf_handle='ZmkzOWYyOHcwdWo4cj')>,
#  <User(id=Nolv, cf_handle='Nolv')>,
#  <User(id=Div.4player, cf_handle='Div.4player')>,
#  <User(id=Tsovak, cf_handle='Tsovak')>,
#  <User(id=jg_in_cf, cf_handle='jg_in_cf')>,
#  <User(id=vaibhav_2003, cf_handle='vaibhav_2003')>,
#  <User(id=GxDf77777, cf_handle='GxDf77777')>,
#  <User(id=xiaoququsd, cf_handle='xiaoququsd')>,
#  <User(id=Circling, cf_handle='Circling')>,
#  <User(id=jacek.karol.rak, cf_handle='jacek.karol.rak')>,
#  <User(id=ohuton_labo, cf_handle='ohuton_labo')>,
#  <User(id=sonder042, cf_handle='sonder042')>,
#  <User(id=shift., cf_handle='shift.')>,
#  <User(id=Cheerio2022, cf_handle='Cheerio2022')>,
#  <User(id=HMAXS, cf_handle='HMAXS')>,
#  <User(id=bashNewbie, cf_handle='bashNewbie')>,
#  <User(id=153floppa, cf_handle='153floppa')>,
#  <User(id=AmiyaBot, cf_handle='AmiyaBot')>,
#  <User(id=baibaiouo, cf_handle='baibaiouo')>,
#  <User(id=rjurisic, cf_handle='rjurisic')>,
#  <User(id=CrazyDave53, cf_handle='CrazyDave53')>,
#  <User(id=meow..meow, cf_handle='meow..meow')>,
#  <User(id=wylTUN, cf_handle='wylTUN')>,
#  <User(id=chaegaedewkindaguy, cf_handle='chaegaedewkindaguy')>,
#  <User(id=violet08, cf_handle='violet08')>,
#  <User(id=kapishv, cf_handle='kapishv')>,
#  <User(id=jaxongir0914, cf_handle='jaxongir0914')>,
#  <User(id=PaoloB, cf_handle='PaoloB')>,
#  <User(id=lin15937, cf_handle='lin15937')>,
#  <User(id=112661, cf_handle='112661')>,
#  <User(id=YSTheGoood, cf_handle='YSTheGoood')>,
#  <User(id=Boca, cf_handle='Boca')>,
#  <User(id=ILabelI, cf_handle='ILabelI')>,
#  <User(id=_Alamin_Bhuiyan_, cf_handle='_Alamin_Bhuiyan_')>,
#  <User(id=Lazy_Lion, cf_handle='Lazy_Lion')>,
#  <User(id=pedrosorio, cf_handle='pedrosorio')>,
#  <User(id=c1120241919, cf_handle='c1120241919')>,
#  <User(id=shivam_751, cf_handle='shivam_751')>,
#  <User(id=ZhixingYi, cf_handle='ZhixingYi')>,
#  <User(id=Pranavk1234, cf_handle='Pranavk1234')>,
#  <User(id=Aurora_Wind, cf_handle='Aurora_Wind')>,
#  <User(id=Poles, cf_handle='Poles')>,
#  <User(id=CJ-_zhuyifan, cf_handle='CJ-_zhuyifan')>,
#  <User(id=sioo_, cf_handle='sioo_')>,
#  <User(id=s8x, cf_handle='s8x')>,
#  <User(id=911Boom, cf_handle='911Boom')>,
#  <User(id=anibitte, cf_handle='anibitte')>,
#  <User(id=vhnvn, cf_handle='vhnvn')>,
#  <User(id=newone2023, cf_handle='newone2023')>,
#  <User(id=maxrgby, cf_handle='maxrgby')>,
#  <User(id=core_huduga, cf_handle='core_huduga')>,
#  <User(id=uppercut, cf_handle='uppercut')>,
#  <User(id=HTyin, cf_handle='HTyin')>,
#  <User(id=cangome, cf_handle='cangome')>,
#  <User(id=ylcs, cf_handle='ylcs')>,
#  <User(id=VTloBong, cf_handle='VTloBong')>,
#  <User(id=kbrcic, cf_handle='kbrcic')>,
#  <User(id=laupm, cf_handle='laupm')>,
#  <User(id=detaomega19, cf_handle='detaomega19')>,
#  <User(id=QwQwf, cf_handle='QwQwf')>,
#  <User(id=yihang_01, cf_handle='yihang_01')>,
#  <User(id=Master_in_2024, cf_handle='Master_in_2024')>,
#  <User(id=Namine, cf_handle='Namine')>,
#  <User(id=Son, cf_handle='Son')>,
#  <User(id=aves, cf_handle='aves')>,
#  <User(id=Aniket_Kumar1, cf_handle='Aniket_Kumar1')>,
#  <User(id=__meow_meow__, cf_handle='__meow_meow__')>,
#  <User(id=HCMUS-HQHuy, cf_handle='HCMUS-HQHuy')>,
#  <User(id=LeHuynhDuc, cf_handle='LeHuynhDuc')>,
#  <User(id=SOSCharlie, cf_handle='SOSCharlie')>,
#  <User(id=DatMomoAgain, cf_handle='DatMomoAgain')>,
#  <User(id=edwin, cf_handle='edwin')>,
#  <User(id=GuomingWu, cf_handle='GuomingWu')>,
#  <User(id=William_xb, cf_handle='William_xb')>,
#  <User(id=kotyakotb, cf_handle='kotyakotb')>,
#  <User(id=conclr, cf_handle='conclr')>,
#  <User(id=errormakers, cf_handle='errormakers')>,
#  <User(id=AkashxOP, cf_handle='AkashxOP')>,
#  <User(id=abe_yadv, cf_handle='abe_yadv')>,
#  <User(id=Matrix10, cf_handle='Matrix10')>,
#  <User(id=ZzzHhhLM, cf_handle='ZzzHhhLM')>,
#  <User(id=Wang_Xiaoguang, cf_handle='Wang_Xiaoguang')>,
#  <User(id=xcvv, cf_handle='xcvv')>,
#  <User(id=metelkov, cf_handle='metelkov')>,
#  <User(id=nobitalovesshizuka, cf_handle='nobitalovesshizuka')>,
#  <User(id=AbracaSora, cf_handle='AbracaSora')>,
#  <User(id=a_codeforces_username, cf_handle='a_codeforces_username')>,
#  <User(id=Nocoldinsummer, cf_handle='Nocoldinsummer')>,
#  <User(id=smallbrainsovamain1, cf_handle='smallbrainsovamain1')>,
#  <User(id=zxcabuser, cf_handle='zxcabuser')>,
#  <User(id=1ightwhite, cf_handle='1ightwhite')>,
#  <User(id=phannguyenquocbao, cf_handle='phannguyenquocbao')>,
#  <User(id=JerryMao, cf_handle='JerryMao')>,
#  <User(id=ccdfw, cf_handle='ccdfw')>,
#  <User(id=Non-CS-Coder, cf_handle='Non-CS-Coder')>,
#  <User(id=javad_asadi, cf_handle='javad_asadi')>,
#  <User(id=nitro_a_grade, cf_handle='nitro_a_grade')>,
#  <User(id=x__h__w__123, cf_handle='x__h__w__123')>,
#  <User(id=IngaleAnkur10, cf_handle='IngaleAnkur10')>,
#  <User(id=StarRiver, cf_handle='StarRiver')>,
#  <User(id=bridgekiller, cf_handle='bridgekiller')>,
#  <User(id=Andrea404, cf_handle='Andrea404')>,
#  <User(id=Zoro238, cf_handle='Zoro238')>,
#  <User(id=RainbowX, cf_handle='RainbowX')>,
#  <User(id=HalkaMerechiBhaiLalpani, cf_handle='HalkaMerechiBhaiLalpani')>,
#  <User(id=CHY2k6BuiDinhQuyen, cf_handle='CHY2k6BuiDinhQuyen')>,
#  <User(id=PARTHO_DAS, cf_handle='PARTHO_DAS')>,
#  <User(id=notaapoorv, cf_handle='notaapoorv')>,
#  <User(id=15372583O23, cf_handle='15372583O23')>,
#  <User(id=HellollWorld, cf_handle='HellollWorld')>,
#  <User(id=Vanjanja, cf_handle='Vanjanja')>,
#  <User(id=QuinnG, cf_handle='QuinnG')>,
#  <User(id=qqcly, cf_handle='qqcly')>,
#  <User(id=rahul4005, cf_handle='rahul4005')>,
#  <User(id=don0thing, cf_handle='don0thing')>,
#  <User(id=SoyTuHusbando, cf_handle='SoyTuHusbando')>,
#  <User(id=spyro, cf_handle='spyro')>,
#  <User(id=Doubleen233, cf_handle='Doubleen233')>,
#  <User(id=hehe113, cf_handle='hehe113')>,
#  <User(id=G01o5R, cf_handle='G01o5R')>,
#  <User(id=devangsvaghani, cf_handle='devangsvaghani')>,
#  <User(id=Pan_ma_ru, cf_handle='Pan_ma_ru')>,
#  <User(id=lovedeep0022, cf_handle='lovedeep0022')>,
#  <User(id=timaktimak, cf_handle='timaktimak')>,
#  <User(id=Pia_owo, cf_handle='Pia_owo')>,
#  <User(id=leolin0214, cf_handle='leolin0214')>,
#  <User(id=hby2004, cf_handle='hby2004')>,
#  <User(id=hnust_lijiahui, cf_handle='hnust_lijiahui')>,
#  <User(id=lqm123, cf_handle='lqm123')>,
#  <User(id=zhligzweru, cf_handle='zhligzweru')>,
#  <User(id=brute_forceCE, cf_handle='brute_forceCE')>,
#  <User(id=TrappedGhost, cf_handle='TrappedGhost')>,
#  <User(id=Rohhy, cf_handle='Rohhy')>,
#  <User(id=Falcon_76, cf_handle='Falcon_76')>,
#  <User(id=hftsincoming, cf_handle='hftsincoming')>,
#  <User(id=CUMT-MJZ, cf_handle='CUMT-MJZ')>,
#  <User(id=singh.bhanu568, cf_handle='singh.bhanu568')>,
#  <User(id=Monatized, cf_handle='Monatized')>,
#  <User(id=star_sea, cf_handle='star_sea')>,
#  <User(id=Jotinha, cf_handle='Jotinha')>,
#  <User(id=xx003, cf_handle='xx003')>,
#  <User(id=Diao_lingg, cf_handle='Diao_lingg')>,
#  <User(id=SantoBlue, cf_handle='SantoBlue')>,
#  <User(id=OLGA233, cf_handle='OLGA233')>,
#  <User(id=Samaun, cf_handle='Samaun')>,
#  <User(id=Jayg000e, cf_handle='Jayg000e')>,
#  <User(id=zhaoyuebo, cf_handle='zhaoyuebo')>,
#  <User(id=creating001, cf_handle='creating001')>,
#  <User(id=pingzhou, cf_handle='pingzhou')>,
#  <User(id=sparkblit, cf_handle='sparkblit')>,
#  <User(id=dydx, cf_handle='dydx')>,
#  <User(id=khuongduy2121, cf_handle='khuongduy2121')>,
#  <User(id=magisterialmessi, cf_handle='magisterialmessi')>,
#  <User(id=Manav_Shah24, cf_handle='Manav_Shah24')>,
#  <User(id=Atharva_Arya2, cf_handle='Atharva_Arya2')>,
#  <User(id=Moonandlight, cf_handle='Moonandlight')>,
#  <User(id=shinever, cf_handle='shinever')>,
#  <User(id=wang_by, cf_handle='wang_by')>,
#  <User(id=daibowen, cf_handle='daibowen')>,
#  <User(id=darthrevenge, cf_handle='darthrevenge')>,
#  <User(id=NMTLSDGRBI2F, cf_handle='NMTLSDGRBI2F')>,
#  <User(id=autoastt, cf_handle='autoastt')>,
#  <User(id=ufan, cf_handle='ufan')>,
#  <User(id=wechicken456, cf_handle='wechicken456')>,
#  <User(id=lozergam, cf_handle='lozergam')>,
#  <User(id=Alexandr_White, cf_handle='Alexandr_White')>,
#  <User(id=unityGamer, cf_handle='unityGamer')>,
#  <User(id=-WIDA-, cf_handle='-WIDA-')>,
#  <User(id=zhmx, cf_handle='zhmx')>,
#  <User(id=LogSingleDog, cf_handle='LogSingleDog')>,
#  <User(id=girlgg, cf_handle='girlgg')>,
#  <User(id=AbeedShaik, cf_handle='AbeedShaik')>,
#  <User(id=yyc4591, cf_handle='yyc4591')>,
#  <User(id=sashastrakhal, cf_handle='sashastrakhal')>,
#  <User(id=The_terminator, cf_handle='The_terminator')>,
#  <User(id=XingU7, cf_handle='XingU7')>,
#  <User(id=300IQQQ, cf_handle='300IQQQ')>,
#  <User(id=G_liver, cf_handle='G_liver')>,
#  <User(id=ppnoonbb, cf_handle='ppnoonbb')>,
#  <User(id=Shri_874, cf_handle='Shri_874')>,
#  <User(id=DmitryLessy, cf_handle='DmitryLessy')>,
#  <User(id=Aditya.Rai, cf_handle='Aditya.Rai')>,
#  <User(id=0-4, cf_handle='0-4')>,
#  <User(id=hunglomdom, cf_handle='hunglomdom')>,
#  <User(id=ASHDIM, cf_handle='ASHDIM')>,
#  <User(id=_nkelkins_, cf_handle='_nkelkins_')>,
#  <User(id=shanguangkabishou, cf_handle='shanguangkabishou')>,
#  <User(id=Phool_gobhi_, cf_handle='Phool_gobhi_')>,
#  <User(id=shubham240, cf_handle='shubham240')>,
#  <User(id=syysongyuyang, cf_handle='syysongyuyang')>,
#  <User(id=AitsukiNakuru1, cf_handle='AitsukiNakuru1')>,
#  <User(id=AitsukiNakuru, cf_handle='AitsukiNakuru')>,
#  <User(id=Whxxxxx318, cf_handle='Whxxxxx318')>,
#  <User(id=TheLibra, cf_handle='TheLibra')>,
#  <User(id=Jarvis2000, cf_handle='Jarvis2000')>,
#  <User(id=5911_S, cf_handle='5911_S')>,
#  <User(id=TimeLimitExceed, cf_handle='TimeLimitExceed')>,
#  <User(id=Aprilend, cf_handle='Aprilend')>,
#  <User(id=shikr02, cf_handle='shikr02')>,
#  <User(id=sto_CarroT5656_orz, cf_handle='sto_CarroT5656_orz')>,
#  <User(id=anandchourasia007, cf_handle='anandchourasia007')>,
#  <User(id=vartika2001, cf_handle='vartika2001')>,
#  <User(id=_Tish_system, cf_handle='_Tish_system')>,
#  <User(id=xug, cf_handle='xug')>,
#  <User(id=Geanina_the_Great, cf_handle='Geanina_the_Great')>,
#  <User(id=EvilTom, cf_handle='EvilTom')>,
#  <User(id=maihu02, cf_handle='maihu02')>,
#  <User(id=KorukinKirill, cf_handle='KorukinKirill')>,
#  <User(id=ShiroRinne, cf_handle='ShiroRinne')>,
#  <User(id=yangchang, cf_handle='yangchang')>,
#  <User(id=bamboo_chen_92518, cf_handle='bamboo_chen_92518')>,
#  <User(id=sarveshkulkarni5, cf_handle='sarveshkulkarni5')>,
#  <User(id=RX93, cf_handle='RX93')>,
#  <User(id=Dr_House_13, cf_handle='Dr_House_13')>,
#  <User(id=sorehadoukana, cf_handle='sorehadoukana')>,
#  <User(id=emir_raze, cf_handle='emir_raze')>,
#  <User(id=Mirx, cf_handle='Mirx')>,
#  <User(id=BaiBaikk, cf_handle='BaiBaikk')>,
#  <User(id=heavenkatana, cf_handle='heavenkatana')>,
#  <User(id=PoorGhost, cf_handle='PoorGhost')>,
#  <User(id=kuchh_bhi, cf_handle='kuchh_bhi')>,
#  <User(id=MaxDYF, cf_handle='MaxDYF')>,
#  <User(id=a_little_cute, cf_handle='a_little_cute')>,
#  <User(id=Amdadul, cf_handle='Amdadul')>,
#  <User(id=restar682, cf_handle='restar682')>,
#  <User(id=11d10xy, cf_handle='11d10xy')>,
#  <User(id=Mumu_sir, cf_handle='Mumu_sir')>,
#  <User(id=Itachi_Uchiha13, cf_handle='Itachi_Uchiha13')>,
#  <User(id=hokihoki, cf_handle='hokihoki')>,
#  <User(id=luoZH111, cf_handle='luoZH111')>,
#  <User(id=__Dreamboat, cf_handle='__Dreamboat')>,
#  <User(id=song, cf_handle='song')>,
#  <User(id=uptime, cf_handle='uptime')>,
#  <User(id=azert9526, cf_handle='azert9526')>,
#  <User(id=crimcrim, cf_handle='crimcrim')>,
#  <User(id=Oliver97, cf_handle='Oliver97')>,
#  <User(id=endless_love, cf_handle='endless_love')>,
#  <User(id=yoogi_kov, cf_handle='yoogi_kov')>,
#  <User(id=Dr_Magnetar, cf_handle='Dr_Magnetar')>,
#  <User(id=Miku_miao, cf_handle='Miku_miao')>,
#  <User(id=Hamzeh_Miqdad, cf_handle='Hamzeh_Miqdad')>,
#  <User(id=songbai, cf_handle='songbai')>,
#  <User(id=KOP, cf_handle='KOP')>,
#  <User(id=chtholly3, cf_handle='chtholly3')>,
#  <User(id=TaawraaT, cf_handle='TaawraaT')>,
#  <User(id=jay_patel_101, cf_handle='jay_patel_101')>,
#  <User(id=ToxiCobra, cf_handle='ToxiCobra')>,
#  <User(id=Mashty, cf_handle='Mashty')>,
#  <User(id=kunjan_, cf_handle='kunjan_')>,
#  <User(id=UnknownFear, cf_handle='UnknownFear')>,
#  <User(id=kingsneverdie1411, cf_handle='kingsneverdie1411')>,
#  <User(id=mucamaca, cf_handle='mucamaca')>,
#  <User(id=_Nadaf_, cf_handle='_Nadaf_')>,
#  <User(id=EileenQueen, cf_handle='EileenQueen')>,
#  <User(id=NathanB, cf_handle='NathanB')>,
#  <User(id=pro_ratan, cf_handle='pro_ratan')>,
#  <User(id=plutusBoy, cf_handle='plutusBoy')>,
#  <User(id=hungpt19, cf_handle='hungpt19')>,
#  <User(id=HHHashmap, cf_handle='HHHashmap')>,
#  <User(id=steli2, cf_handle='steli2')>,
#  <User(id=Jeresalen, cf_handle='Jeresalen')>,
#  <User(id=Cross.Entropy, cf_handle='Cross.Entropy')>,
#  <User(id=nehan_der_thal, cf_handle='nehan_der_thal')>,
#  <User(id=Essar_, cf_handle='Essar_')>,
#  <User(id=Starstream120225, cf_handle='Starstream120225')>,
#  <User(id=Prabhav10, cf_handle='Prabhav10')>,
#  <User(id=IloveYukino, cf_handle='IloveYukino')>,
#  <User(id=Inori166, cf_handle='Inori166')>,
#  <User(id=Fadil, cf_handle='Fadil')>,
#  <User(id=gipnag, cf_handle='gipnag')>,
#  <User(id=liaiyang, cf_handle='liaiyang')>,
#  <User(id=wu_la_la, cf_handle='wu_la_la')>,
#  <User(id=Dragono63, cf_handle='Dragono63')>,
#  <User(id=basalt_lava, cf_handle='basalt_lava')>,
#  <User(id=hnust_jiangly, cf_handle='hnust_jiangly')>,
#  <User(id=TypeYippie, cf_handle='TypeYippie')>,
#  <User(id=Elderidge, cf_handle='Elderidge')>,
#  <User(id=AlexEvans, cf_handle='AlexEvans')>,
#  <User(id=Ron_Chen, cf_handle='Ron_Chen')>,
#  <User(id=Tigervictor12, cf_handle='Tigervictor12')>,
#  <User(id=Wutip, cf_handle='Wutip')>,
#  <User(id=moridoufu, cf_handle='moridoufu')>,
#  <User(id=Kartoshkasmyasom, cf_handle='Kartoshkasmyasom')>,
#  <User(id=ComboMAX, cf_handle='ComboMAX')>,
#  <User(id=paidaxing123, cf_handle='paidaxing123')>,
#  <User(id=IbrahimHabib, cf_handle='IbrahimHabib')>,
#  <User(id=Royal, cf_handle='Royal')>,
#  <User(id=Gujialiang270, cf_handle='Gujialiang270')>,
#  <User(id=jmichael, cf_handle='jmichael')>,
#  <User(id=zhaojunchao, cf_handle='zhaojunchao')>,
#  <User(id=Moropan, cf_handle='Moropan')>,
#  <User(id=Nitin_kholu, cf_handle='Nitin_kholu')>,
#  <User(id=Firestone, cf_handle='Firestone')>,
#  <User(id=Sarvesh43, cf_handle='Sarvesh43')>,
#  <User(id=totally_securite, cf_handle='totally_securite')>,
#  <User(id=system_1, cf_handle='system_1')>,
#  <User(id=DrZero0, cf_handle='DrZero0')>,
#  <User(id=JaishreeramCoder, cf_handle='JaishreeramCoder')>,
#  <User(id=pattagobhii, cf_handle='pattagobhii')>,
#  <User(id=Masttf, cf_handle='Masttf')>,
#  <User(id=reawakened, cf_handle='reawakened')>,
#  <User(id=Areshki, cf_handle='Areshki')>,
#  <User(id=TiredRetiredThread, cf_handle='TiredRetiredThread')>,
#  <User(id=SaiRohan, cf_handle='SaiRohan')>,
#  <User(id=1152237439, cf_handle='1152237439')>,
#  <User(id=Pinkandpig, cf_handle='Pinkandpig')>,
#  <User(id=Just_sri, cf_handle='Just_sri')>,
#  <User(id=Fangio, cf_handle='Fangio')>,
#  <User(id=Hanx16Kira_, cf_handle='Hanx16Kira_')>,
#  <User(id=LuvLetturr, cf_handle='LuvLetturr')>,
#  <User(id=RAV_IITM, cf_handle='RAV_IITM')>,
#  <User(id=shidou, cf_handle='shidou')>,
#  <User(id=pakde_gaye, cf_handle='pakde_gaye')>,
#  <User(id=B0b_114514, cf_handle='B0b_114514')>,
#  <User(id=HaoxuanXIE, cf_handle='HaoxuanXIE')>,
#  <User(id=wfjfjx, cf_handle='wfjfjx')>,
#  <User(id=Leonardo16, cf_handle='Leonardo16')>,
#  <User(id=Ronak23, cf_handle='Ronak23')>,
#  <User(id=gluestick12, cf_handle='gluestick12')>,
#  <User(id=ahmad_alghadban, cf_handle='ahmad_alghadban')>,
#  <User(id=karashi_, cf_handle='karashi_')>,
#  <User(id=thesuaveguy, cf_handle='thesuaveguy')>,
#  <User(id=Zandler, cf_handle='Zandler')>,
#  <User(id=Yeahh_, cf_handle='Yeahh_')>,
#  <User(id=Rowd, cf_handle='Rowd')>,
#  <User(id=stup_bitch, cf_handle='stup_bitch')>,
#  <User(id=quangthangg, cf_handle='quangthangg')>,
#  <User(id=beiwwen, cf_handle='beiwwen')>,
#  <User(id=TrevPeak, cf_handle='TrevPeak')>,
#  <User(id=Haz_Begonia, cf_handle='Haz_Begonia')>,
#  <User(id=kirillveshnyakov, cf_handle='kirillveshnyakov')>,
#  <User(id=Wfame, cf_handle='Wfame')>,
#  <User(id=koorui, cf_handle='koorui')>,
#  <User(id=Fury_Tong_T0, cf_handle='Fury_Tong_T0')>,
#  <User(id=Ladamalina, cf_handle='Ladamalina')>,
#  <User(id=SN0WM4N, cf_handle='SN0WM4N')>,
#  <User(id=bob118, cf_handle='bob118')>,
#  <User(id=zhangrj, cf_handle='zhangrj')>,
#  <User(id=TheIridescentOne, cf_handle='TheIridescentOne')>,
#  <User(id=Comentropy, cf_handle='Comentropy')>,
#  <User(id=naam_me_kya_rakha_ha, cf_handle='naam_me_kya_rakha_ha')>,
#  <User(id=Art.twink, cf_handle='Art.twink')>,
#  <User(id=Beast_376, cf_handle='Beast_376')>,
#  <User(id=markthitrin, cf_handle='markthitrin')>,
#  <User(id=miyukin, cf_handle='miyukin')>,
#  <User(id=Luck1829, cf_handle='Luck1829')>,
#  <User(id=rougenn, cf_handle='rougenn')>,
#  <User(id=nondeterministic, cf_handle='nondeterministic')>,
#  <User(id=Bibu54123, cf_handle='Bibu54123')>,
#  <User(id=...._....__...___, cf_handle='...._....__...___')>,
#  <User(id=brianlee0415, cf_handle='brianlee0415')>,
#  <User(id=Pirate-King, cf_handle='Pirate-King')>,
#  <User(id=oh_my_shy, cf_handle='oh_my_shy')>,
#  <User(id=viniciusth, cf_handle='viniciusth')>,
#  <User(id=BTK, cf_handle='BTK')>,
#  <User(id=RernaG, cf_handle='RernaG')>,
#  <User(id=I_Will_Marry_Ngoc, cf_handle='I_Will_Marry_Ngoc')>,
#  <User(id=zhassyn, cf_handle='zhassyn')>,
#  <User(id=bkdn23.leevox, cf_handle='bkdn23.leevox')>,
#  <User(id=7ms, cf_handle='7ms')>,
#  <User(id=Franktastic, cf_handle='Franktastic')>,
#  <User(id=efdsa, cf_handle='efdsa')>,
#  <User(id=WilsonKorotkevich, cf_handle='WilsonKorotkevich')>,
#  <User(id=sobijain_m31, cf_handle='sobijain_m31')>,
#  <User(id=tushar_314, cf_handle='tushar_314')>,
#  <User(id=Zoro, cf_handle='Zoro')>,
#  <User(id=enxiayy, cf_handle='enxiayy')>,
#  <User(id=adityachauhan2501, cf_handle='adityachauhan2501')>,
#  <User(id=daulatojha17, cf_handle='daulatojha17')>,
#  <User(id=space_rider, cf_handle='space_rider')>,
#  <User(id=daviedu, cf_handle='daviedu')>,
#  <User(id=Silverboi, cf_handle='Silverboi')>,
#  <User(id=Nekoya, cf_handle='Nekoya')>,
#  <User(id=_r_S20, cf_handle='_r_S20')>,
#  <User(id=octane, cf_handle='octane')>,
#  <User(id=nosaboy, cf_handle='nosaboy')>,
#  <User(id=pseong, cf_handle='pseong')>,
#  <User(id=sahil_singh3, cf_handle='sahil_singh3')>,
#  <User(id=Andy, cf_handle='Andy')>,
#  <User(id=2005zhw, cf_handle='2005zhw')>,
#  <User(id=Niraj0433, cf_handle='Niraj0433')>,
#  <User(id=xiaofangyi, cf_handle='xiaofangyi')>,
#  <User(id=Only., cf_handle='Only.')>,
#  <User(id=WESLIE233123, cf_handle='WESLIE233123')>,
#  <User(id=Xiaozzz, cf_handle='Xiaozzz')>,
#  <User(id=sam_28, cf_handle='sam_28')>,
#  <User(id=CoderCharlie, cf_handle='CoderCharlie')>,
#  <User(id=iDaly, cf_handle='iDaly')>,
#  <User(id=AhsanRandhawa, cf_handle='AhsanRandhawa')>,
#  <User(id=TwilightSparkle, cf_handle='TwilightSparkle')>,
#  <User(id=zarubin, cf_handle='zarubin')>,
#  <User(id=Zinn, cf_handle='Zinn')>,
#  <User(id=RandomChicken, cf_handle='RandomChicken')>,
#  <User(id=turuthok, cf_handle='turuthok')>,
#  <User(id=privateer, cf_handle='privateer')>,
#  <User(id=minus_one_madarchod, cf_handle='minus_one_madarchod')>,
#  <User(id=SainadhSN2, cf_handle='SainadhSN2')>,
#  <User(id=GuEnhao, cf_handle='GuEnhao')>,
#  <User(id=Alear, cf_handle='Alear')>,
#  <User(id=shivambhadani_, cf_handle='shivambhadani_')>,
#  <User(id=MoSooN, cf_handle='MoSooN')>,
#  <User(id=trap, cf_handle='trap')>,
#  <User(id=Acesh, cf_handle='Acesh')>,
#  <User(id=pawanrawat, cf_handle='pawanrawat')>,
#  <User(id=hungeazy, cf_handle='hungeazy')>,
#  <User(id=GrootForces, cf_handle='GrootForces')>,
#  <User(id=Man1nM00N, cf_handle='Man1nM00N')>,
#  <User(id=3mara, cf_handle='3mara')>,
#  <User(id=Greedious, cf_handle='Greedious')>,
#  <User(id=YSGU, cf_handle='YSGU')>,
#  <User(id=ijustwanttosleep, cf_handle='ijustwanttosleep')>,
#  <User(id=Jinesh1, cf_handle='Jinesh1')>,
#  <User(id=Me_Happy_Me_No_Sad, cf_handle='Me_Happy_Me_No_Sad')>,
#  <User(id=italianDefence, cf_handle='italianDefence')>,
#  <User(id=hai_sol2008, cf_handle='hai_sol2008')>,
#  <User(id=Tzak, cf_handle='Tzak')>,
#  <User(id=Chronosonder, cf_handle='Chronosonder')>,
#  <User(id=org., cf_handle='org.')>,
#  <User(id=Qiu_yi, cf_handle='Qiu_yi')>,
#  <User(id=xyfern, cf_handle='xyfern')>,
#  <User(id=yunzhilin, cf_handle='yunzhilin')>,
#  <User(id=xie_lzh, cf_handle='xie_lzh')>,
#  <User(id=KeroQ, cf_handle='KeroQ')>,
#  <User(id=racingheart, cf_handle='racingheart')>,
#  <User(id=jotave, cf_handle='jotave')>,
#  <User(id=get_me_out, cf_handle='get_me_out')>,
#  <User(id=gauravpramodwadhai07, cf_handle='gauravpramodwadhai07')>,
#  <User(id=blobbot, cf_handle='blobbot')>,
#  <User(id=Biubiu0919, cf_handle='Biubiu0919')>,
#  <User(id=unforgettablepl, cf_handle='unforgettablepl')>,
#  <User(id=hahawa, cf_handle='hahawa')>,
#  <User(id=San_Cai, cf_handle='San_Cai')>,
#  <User(id=__radhe__radhe, cf_handle='__radhe__radhe')>,
#  <User(id=Akamu, cf_handle='Akamu')>,
#  <User(id=eriktse, cf_handle='eriktse')>,
#  <User(id=oviyan_gandhi, cf_handle='oviyan_gandhi')>,
#  <User(id=pancake5000, cf_handle='pancake5000')>,
#  <User(id=hooman_7, cf_handle='hooman_7')>,
#  <User(id=aman_k29, cf_handle='aman_k29')>,
#  <User(id=tuna_fly, cf_handle='tuna_fly')>,
#  <User(id=shreyanshshikhar2910, cf_handle='shreyanshshikhar2910')>,
#  <User(id=Georggg999, cf_handle='Georggg999')>,
#  <User(id=Kiramus, cf_handle='Kiramus')>,
#  <User(id=Sem04ka, cf_handle='Sem04ka')>,
#  <User(id=Zhddd_, cf_handle='Zhddd_')>,
#  <User(id=joacru, cf_handle='joacru')>,
#  <User(id=UT2407, cf_handle='UT2407')>,
#  <User(id=Ismail_Alrifai, cf_handle='Ismail_Alrifai')>,
#  <User(id=hophamsailam, cf_handle='hophamsailam')>,
#  <User(id=nayabanayahai, cf_handle='nayabanayahai')>,
#  <User(id=crabcrabcrab, cf_handle='crabcrabcrab')>,
#  <User(id=abhay_k47, cf_handle='abhay_k47')>,
#  <User(id=MoYuToGo, cf_handle='MoYuToGo')>,
#  <User(id=SuAnRan, cf_handle='SuAnRan')>,
#  <User(id=SirAnder, cf_handle='SirAnder')>,
#  <User(id=cdd, cf_handle='cdd')>,
#  <User(id=myj128128, cf_handle='myj128128')>,
#  <User(id=Yumesekai239iscomingback, cf_handle='Yumesekai239iscomingback')>,
#  <User(id=Itnes, cf_handle='Itnes')>,
#  <User(id=neugis, cf_handle='neugis')>,
#  <User(id=bedupako, cf_handle='bedupako')>,
#  <User(id=mxDawdle, cf_handle='mxDawdle')>,
#  <User(id=Spaseeker, cf_handle='Spaseeker')>,
#  <User(id=depresed_k1d, cf_handle='depresed_k1d')>,
#  <User(id=Sastatourist2004, cf_handle='Sastatourist2004')>,
#  <User(id=schant, cf_handle='schant')>,
#  <User(id=ThiNoSuy, cf_handle='ThiNoSuy')>,
#  <User(id=tryGrind, cf_handle='tryGrind')>,
#  <User(id=dxm, cf_handle='dxm')>,
#  <User(id=Shehuinitiandie, cf_handle='Shehuinitiandie')>,
#  <User(id=hjxddl, cf_handle='hjxddl')>,
#  <User(id=Haitang0520, cf_handle='Haitang0520')>,
#  <User(id=virat1906, cf_handle='virat1906')>,
#  <User(id=themm1, cf_handle='themm1')>,
#  <User(id=jainaditya8464, cf_handle='jainaditya8464')>,
#  <User(id=Jungly, cf_handle='Jungly')>,
#  <User(id=night.watchman, cf_handle='night.watchman')>,
#  <User(id=BellZhong, cf_handle='BellZhong')>,
#  <User(id=funuo, cf_handle='funuo')>,
#  <User(id=Maltaran, cf_handle='Maltaran')>,
#  <User(id=NikhilSharma26, cf_handle='NikhilSharma26')>,
#  <User(id=mic_Rationale, cf_handle='mic_Rationale')>,
#  <User(id=htnaver, cf_handle='htnaver')>,
#  <User(id=CS_17, cf_handle='CS_17')>,
#  <User(id=Orange0110, cf_handle='Orange0110')>,
#  <User(id=DanilaOdesser, cf_handle='DanilaOdesser')>,
#  <User(id=Deep__Blue, cf_handle='Deep__Blue')>,
#  <User(id=Akarachudra, cf_handle='Akarachudra')>,
#  <User(id=partially_unretired_user, cf_handle='partially_unretired_user')>,
#  <User(id=TselmegKh, cf_handle='TselmegKh')>,
#  <User(id=aashishraghav627, cf_handle='aashishraghav627')>,
#  <User(id=ShiHaoHu, cf_handle='ShiHaoHu')>,
#  <User(id=virapaksa, cf_handle='virapaksa')>,
#  <User(id=Kosmo00, cf_handle='Kosmo00')>,
#  <User(id=chaharutkarsh03, cf_handle='chaharutkarsh03')>,
#  <User(id=NO21TOT, cf_handle='NO21TOT')>,
#  <User(id=justapasserby, cf_handle='justapasserby')>,
#  <User(id=Sad_oh1ld, cf_handle='Sad_oh1ld')>,
#  <User(id=little_dog, cf_handle='little_dog')>,
#  <User(id=Accelerator., cf_handle='Accelerator.')>,
#  <User(id=ksodp, cf_handle='ksodp')>,
#  <User(id=GoldenPearl, cf_handle='GoldenPearl')>,
#  <User(id=hmmhnopro, cf_handle='hmmhnopro')>,
#  <User(id=cffff2, cf_handle='cffff2')>,
#  <User(id=gucci0512, cf_handle='gucci0512')>,
#  <User(id=helloZ, cf_handle='helloZ')>,
#  <User(id=Piashy, cf_handle='Piashy')>,
#  <User(id=.cO_Co., cf_handle='.cO_Co.')>,
#  <User(id=Pacifista, cf_handle='Pacifista')>,
#  <User(id=aktowon, cf_handle='aktowon')>,
#  <User(id=system_test.fail, cf_handle='system_test.fail')>,
#  <User(id=lalaouye, cf_handle='lalaouye')>,
#  <User(id=17_Msd, cf_handle='17_Msd')>,
#  <User(id=Nanuyyyy, cf_handle='Nanuyyyy')>,
#  <User(id=opPO, cf_handle='opPO')>,
#  <User(id=30rakirs, cf_handle='30rakirs')>,
#  <User(id=Polygon_Rac, cf_handle='Polygon_Rac')>,
#  <User(id=MD_DM, cf_handle='MD_DM')>,
#  <User(id=WFeng, cf_handle='WFeng')>,
#  <User(id=le_banner, cf_handle='le_banner')>,
#  <User(id=MithilaReich, cf_handle='MithilaReich')>,
#  <User(id=Age8, cf_handle='Age8')>,
#  <User(id=chenjunxiu, cf_handle='chenjunxiu')>,
#  <User(id=shreyank_banakar, cf_handle='shreyank_banakar')>,
#  <User(id=octaneal, cf_handle='octaneal')>,
#  <User(id=Grapefruit_Earth, cf_handle='Grapefruit_Earth')>,
#  <User(id=Miguel0312, cf_handle='Miguel0312')>,
#  <User(id=sloppy_coder, cf_handle='sloppy_coder')>,
#  <User(id=CSUST_GXL, cf_handle='CSUST_GXL')>,
#  <User(id=lpk15014, cf_handle='lpk15014')>,
#  <User(id=Epalithy, cf_handle='Epalithy')>,
#  <User(id=vuhuydiet, cf_handle='vuhuydiet')>,
#  <User(id=akash472sinha, cf_handle='akash472sinha')>,
#  <User(id=aryansingh27, cf_handle='aryansingh27')>,
#  <User(id=Vasu_, cf_handle='Vasu_')>,
#  <User(id=mingyun1343, cf_handle='mingyun1343')>,
#  <User(id=Mahm2od, cf_handle='Mahm2od')>,
#  <User(id=qwerty0110, cf_handle='qwerty0110')>,
#  <User(id=motsuni04, cf_handle='motsuni04')>,
#  <User(id=Sua_GGG, cf_handle='Sua_GGG')>,
#  <User(id=TeqArine, cf_handle='TeqArine')>,
#  <User(id=Sheber, cf_handle='Sheber')>,
#  <User(id=TachGiaiVOI2025, cf_handle='TachGiaiVOI2025')>,
#  <User(id=new-wave, cf_handle='new-wave')>,
#  <User(id=poplpr, cf_handle='poplpr')>,
#  <User(id=detective...dots, cf_handle='detective...dots')>,
#  <User(id=AndiR, cf_handle='AndiR')>,
#  <User(id=huangbrother, cf_handle='huangbrother')>,
#  <User(id=azhan0222, cf_handle='azhan0222')>,
#  <User(id=LZiK, cf_handle='LZiK')>,
#  <User(id=vedprakashsingh216, cf_handle='vedprakashsingh216')>,
#  <User(id=Bao_Lam, cf_handle='Bao_Lam')>,
#  <User(id=7marflow, cf_handle='7marflow')>,
#  <User(id=FeSO4.7H2O, cf_handle='FeSO4.7H2O')>,
#  <User(id=evilboy_, cf_handle='evilboy_')>,
#  <User(id=a_l_i_r_e_z_a, cf_handle='a_l_i_r_e_z_a')>,
#  <User(id=UltraMarine, cf_handle='UltraMarine')>,
#  <User(id=ringup, cf_handle='ringup')>,
#  <User(id=zhandosayupov, cf_handle='zhandosayupov')>,
#  <User(id=Stepan777, cf_handle='Stepan777')>,
#  <User(id=azad_rippah, cf_handle='azad_rippah')>,
#  <User(id=dhruvsh_1729, cf_handle='dhruvsh_1729')>,
#  <User(id=vaiibhav75, cf_handle='vaiibhav75')>,
#  <User(id=darklight4414, cf_handle='darklight4414')>,
#  <User(id=its-ma7moud, cf_handle='its-ma7moud')>,
#  <User(id=1e-9, cf_handle='1e-9')>,
#  <User(id=pyonth, cf_handle='pyonth')>,
#  <User(id=shamir0xe, cf_handle='shamir0xe')>,
#  <User(id=Code4FreakingFun, cf_handle='Code4FreakingFun')>,
#  <User(id=autunm_dream, cf_handle='autunm_dream')>,
#  <User(id=Parth_1502, cf_handle='Parth_1502')>,
#  <User(id=zyinmiserror, cf_handle='zyinmiserror')>,
#  <User(id=Aryan_6400, cf_handle='Aryan_6400')>,
#  <User(id=.out, cf_handle='.out')>,
#  <User(id=Kaihonohane01, cf_handle='Kaihonohane01')>,
#  <User(id=YWDJ, cf_handle='YWDJ')>,
#  <User(id=nanxiang899, cf_handle='nanxiang899')>,
#  <User(id=Ramavath_lalu, cf_handle='Ramavath_lalu')>,
#  <User(id=raudel25, cf_handle='raudel25')>,
#  <User(id=kitekat1__4, cf_handle='kitekat1__4')>,
#  <User(id=pjych1, cf_handle='pjych1')>,
#  <User(id=Rudovich, cf_handle='Rudovich')>,
#  <User(id=Dingzixuan, cf_handle='Dingzixuan')>,
#  <User(id=code_hardik, cf_handle='code_hardik')>,
#  <User(id=ab0bus228, cf_handle='ab0bus228')>,
#  <User(id=BRL_, cf_handle='BRL_')>,
#  <User(id=adambiel, cf_handle='adambiel')>,
#  <User(id=mystery_1, cf_handle='mystery_1')>,
#  <User(id=RaquelFolz, cf_handle='RaquelFolz')>,
#  <User(id=nhatvpm, cf_handle='nhatvpm')>,
#  <User(id=yellow_13, cf_handle='yellow_13')>,
#  <User(id=usx21328, cf_handle='usx21328')>,
#  <User(id=litachloveyou, cf_handle='litachloveyou')>,
#  <User(id=aman0037, cf_handle='aman0037')>,
#  <User(id=dmkwis, cf_handle='dmkwis')>,
#  <User(id=kai_wei, cf_handle='kai_wei')>,
#  <User(id=RetiredRmdanJr, cf_handle='RetiredRmdanJr')>,
#  <User(id=gargvinayak444, cf_handle='gargvinayak444')>,
#  <User(id=woshigou, cf_handle='woshigou')>,
#  <User(id=chatgpt_pro_max, cf_handle='chatgpt_pro_max')>,
#  <User(id=ritiwij, cf_handle='ritiwij')>,
#  <User(id=ItsBufu, cf_handle='ItsBufu')>,
#  <User(id=soumit915, cf_handle='soumit915')>,
#  <User(id=abdelrhmanezzat, cf_handle='abdelrhmanezzat')>,
#  <User(id=bkdn23.ryujin, cf_handle='bkdn23.ryujin')>,
#  <User(id=zuu44862, cf_handle='zuu44862')>,
#  <User(id=Bynner, cf_handle='Bynner')>,
#  <User(id=AccountClosed, cf_handle='AccountClosed')>,
#  <User(id=infrapolar, cf_handle='infrapolar')>,
#  <User(id=Haire, cf_handle='Haire')>,
#  <User(id=sleepaday, cf_handle='sleepaday')>,
#  <User(id=_Silent._.Killer_, cf_handle='_Silent._.Killer_')>,
#  <User(id=Daidaishu, cf_handle='Daidaishu')>,
#  <User(id=hhgzeng, cf_handle='hhgzeng')>,
#  <User(id=sachan_nakshatra, cf_handle='sachan_nakshatra')>,
#  <User(id=mina_nasser, cf_handle='mina_nasser')>,
#  <User(id=weiuou, cf_handle='weiuou')>,
#  <User(id=shawn_sheep, cf_handle='shawn_sheep')>,
#  <User(id=Dhananjaycoder, cf_handle='Dhananjaycoder')>,
#  <User(id=CodeGPT, cf_handle='CodeGPT')>,
#  <User(id=lo_brainer, cf_handle='lo_brainer')>,
#  <User(id=Bhavya_3, cf_handle='Bhavya_3')>,
#  <User(id=yb13558h, cf_handle='yb13558h')>,
#  <User(id=HatanoKokorowillwinioi, cf_handle='HatanoKokorowillwinioi')>,
#  <User(id=itzMina, cf_handle='itzMina')>,
#  <User(id=pvtr, cf_handle='pvtr')>,
#  <User(id=golu_0409, cf_handle='golu_0409')>,
#  <User(id=Nfs.88, cf_handle='Nfs.88')>,
#  <User(id=ammar_shaikh, cf_handle='ammar_shaikh')>,
#  <User(id=frog007, cf_handle='frog007')>,
#  <User(id=byurak, cf_handle='byurak')>,
#  <User(id=___Sherry___, cf_handle='___Sherry___')>,
#  <User(id=HJR_, cf_handle='HJR_')>,
#  <User(id=INMAK, cf_handle='INMAK')>,
#  <User(id=LinkinPony, cf_handle='LinkinPony')>,
#  <User(id=mqnu00, cf_handle='mqnu00')>,
#  <User(id=Trustfulcomic, cf_handle='Trustfulcomic')>,
#  <User(id=QianSui, cf_handle='QianSui')>,
#  <User(id=Nekoyo, cf_handle='Nekoyo')>,
#  <User(id=imtx, cf_handle='imtx')>,
#  <User(id=luck99, cf_handle='luck99')>,
#  <User(id=Garendaxe, cf_handle='Garendaxe')>,
#  <User(id=FekoKarels, cf_handle='FekoKarels')>,
#  <User(id=normalize, cf_handle='normalize')>,
#  <User(id=shubh_025, cf_handle='shubh_025')>,
#  <User(id=Al_Fahim, cf_handle='Al_Fahim')>,
#  <User(id=_jfc_, cf_handle='_jfc_')>,
#  <User(id=shuai_, cf_handle='shuai_')>,
#  <User(id=agjignesh, cf_handle='agjignesh')>,
#  <User(id=tchuana4, cf_handle='tchuana4')>,
#  <User(id=xiaolianyi, cf_handle='xiaolianyi')>,
#  <User(id=-Cap1taL-, cf_handle='-Cap1taL-')>,
#  <User(id=CYhuang, cf_handle='CYhuang')>,
#  <User(id=anshmaurya2908, cf_handle='anshmaurya2908')>,
#  <User(id=dushman1029, cf_handle='dushman1029')>,
#  <User(id=lil_himick, cf_handle='lil_himick')>,
#  <User(id=kimnattanan, cf_handle='kimnattanan')>,
#  <User(id=oberyn_martell, cf_handle='oberyn_martell')>,
#  <User(id=XiaoTieLa, cf_handle='XiaoTieLa')>,
#  <User(id=Ketch0p, cf_handle='Ketch0p')>,
#  <User(id=Dr_Glitch, cf_handle='Dr_Glitch')>,
#  <User(id=FullMetalChains, cf_handle='FullMetalChains')>,
#  <User(id=khajaba, cf_handle='khajaba')>,
#  <User(id=AlixPeigue, cf_handle='AlixPeigue')>,
#  <User(id=darklight13, cf_handle='darklight13')>,
#  <User(id=Yannam_Yeswanth, cf_handle='Yannam_Yeswanth')>,
#  <User(id=acasus, cf_handle='acasus')>,
#  <User(id=gxp123, cf_handle='gxp123')>,
#  <User(id=RiddhiA, cf_handle='RiddhiA')>,
#  <User(id=vajaba, cf_handle='vajaba')>,
#  <User(id=nidhi0408, cf_handle='nidhi0408')>,
#  <User(id=sonamoo, cf_handle='sonamoo')>,
#  <User(id=Ankitonfire, cf_handle='Ankitonfire')>,
#  <User(id=ccsu_zx, cf_handle='ccsu_zx')>,
#  <User(id=otac, cf_handle='otac')>,
#  <User(id=Romakolesn, cf_handle='Romakolesn')>,
#  <User(id=Hamood_Hamood, cf_handle='Hamood_Hamood')>,
#  <User(id=galimchk, cf_handle='galimchk')>,
#  <User(id=mecer-alex, cf_handle='mecer-alex')>,
#  <User(id=Nomia, cf_handle='Nomia')>,
#  <User(id=PurpleGym, cf_handle='PurpleGym')>,
#  <User(id=Conan1302, cf_handle='Conan1302')>,
#  <User(id=SugmaDic, cf_handle='SugmaDic')>,
#  <User(id=Aucinilhyoegunh, cf_handle='Aucinilhyoegunh')>,
#  <User(id=IAmiron, cf_handle='IAmiron')>,
#  <User(id=CanderFlower, cf_handle='CanderFlower')>,
#  <User(id=JainMudit, cf_handle='JainMudit')>,
#  <User(id=SNM, cf_handle='SNM')>,
#  <User(id=AmrAhmed110, cf_handle='AmrAhmed110')>,
#  <User(id=Overwatch_fan, cf_handle='Overwatch_fan')>,
#  <User(id=lit2021011, cf_handle='lit2021011')>,
#  <User(id=hey_there_sweetie_, cf_handle='hey_there_sweetie_')>,
#  <User(id=AGG, cf_handle='AGG')>,
#  <User(id=KazoeYakuman, cf_handle='KazoeYakuman')>,
#  <User(id=rajkshitij573, cf_handle='rajkshitij573')>,
#  <User(id=TLE_lord, cf_handle='TLE_lord')>,
#  <User(id=Ali_Alp_Yazici, cf_handle='Ali_Alp_Yazici')>,
#  <User(id=bubatinho, cf_handle='bubatinho')>,
#  <User(id=szh3543304389, cf_handle='szh3543304389')>,
#  <User(id=hongjinjian, cf_handle='hongjinjian')>,
#  <User(id=rom777, cf_handle='rom777')>,
#  <User(id=Rhaenyra__, cf_handle='Rhaenyra__')>,
#  <User(id=nguyentunglam, cf_handle='nguyentunglam')>,
#  ...]

# %%
from app import db_utils

db_utils.__dir__()
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__file__',
#  '__cached__',
#  '__builtins__',
#  'pd',
#  'inspect',
#  'text',
#  'MetaData',
#  'declarative_base',
#  'contextmanager',
#  'Base',
#  'SessionLocal',
#  'engine',
#  'models',
#  'json',
#  'os',
#  'datetime',
#  'create_engine',
#  'reset_db',
#  'drop_table',
#  'to_df',
#  'get_table_names',
#  'count_records',
#  'backup_table',
#  'get_table_schema',
#  'get_session',
#  'execute_raw_query']
