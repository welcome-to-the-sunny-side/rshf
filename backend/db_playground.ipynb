# %%
from app.db_utils import *

# %%
df = to_df("users")

# %%
df[df.is_registered == False]
# Out:
#               user_id  role       cf_handle atcoder_handle codechef_handle  \
# 45376       xhx114514  user       xhx114514           None            None
# 45377          Acetyl  user          Acetyl           None            None
# 45378       Anonymely  user       Anonymely           None            None
# 45379     chenyifanlx  user     chenyifanlx           None            None
# 45380     Hydroxythio  user     Hydroxythio           None            None
# ...               ...   ...             ...            ...             ...
# 53255        shuwenhe  user        shuwenhe           None            None
# 53256         naker_n  user         naker_n           None            None
# 53257  bhordevashish0  user  bhordevashish0           None            None
# 53258     DLUTZeratul  user     DLUTZeratul           None            None
# 53259        xlpg0317  user        xlpg0317           None            None
#
#       twitter_handle                 email_id  is_registered  \
# ...
