# %%
from app.db_utils import *
from app.models import *

# %%
db = SessionLocal()

# %%
usr = db.query(User).filter(User.user_id == "misaki").first()

# %%
db.delete(usr)
db.commit()

# %%
df = to_df("users")
df[df.user_id == "misaki"]
# Out:
#       user_id  role cf_handle atcoder_handle codechef_handle twitter_handle  \
# 53260  misaki  user    misaki           None            None           None
#
#                       email_id  is_registered  \
# 53260  not_registered@rshf.net          False
#
#                                          hashed_password  \
# 53260  QElmgTzn73DZayIuIhmlmn0o6PlEdOE8QHgvnH70XeNuG8...
#
#                        timestamp
# 53260 2025-06-06 10:05:32.208471

# %%
db.rollback()

db.add_all(
    [
        User(
            user_id = "misaki",
            cf_handle = "misaki",
            is_registered = False,
        )
    ]
)
db.commit()
